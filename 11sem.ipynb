# %% [markdown]
# <a href="https://colab.research.google.com/github/MchlKilv/C-sharp_Seminar-s/blob/main/11sem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Библиотека для работы с табличными данными
import pandas as pd

# %%
df1 = pd.read_csv('sample_data/california_housing_test.csv')

# %%
# Максимальное значение
print(df1['median_house_value'].max())
# Минимальное значение
print(df1['median_house_value'].min())
# Out:
# 500001.0
# 22500.0

# %%
df1.loc[df1['median_income'] == 3.1250, ['median_house_value', 'median_income']]
# Out:
#       median_house_value  median_income
# 207             167100.0          3.125
# 784             233300.0          3.125
# 904             156300.0          3.125
# 1908            219900.0          3.125

# %%
max_population = df1[df1['median_house_value'] == df1['median_house_value'].min()]['population'].max()
print(max_population)
# Out:
# 1230.0
